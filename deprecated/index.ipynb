# %% [markdown]
# ---
# title: "Electricity Sector Climate Data Guide"
# author:
#   - name: Louis-Philippe Caron
#     affiliations:
#       - name: Ouranos
#         url: https://www.ouranos.ca
#       - city: Montreal
#       - state: QC
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#     degrees:
#       - PhD
#   - name: Marco Braun
#     affiliations:
#       - name: Ouranos
#         url: https://www.ouranos.ca
#       - city: Montreal
#       - state: QC
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#     degrees:
#       - PhD
#   - name: Sarah-Claude Bourdeau-Goulet
#     affiliation:
#       - name: Ouranos
#         url: https://www.ouranos.ca
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#   - name: Kurt Kornelsen
#     affiliation:
#       - name: Ontario Power Generation
#         url: https://www.opg.com/
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#     degrees:
#       - PhD
#   - name: Jongho Keum
#     affiliation:
#       - name: McMaster University
#         url: https://www.mcmaster.ca/
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#     degrees:
#       - PhD
#   - name: Rasel Sheikh
#     affiliation:
#       - name: McMaster University
#         url: https://www.mcmaster.ca/
#     orcid: 0000-0001-2345-6789
#     email: maybe@not.com
#     degrees:
#       - PhD
#
# date: today
# ---
#
#
# ___
# Built with Quarto - To learn more about Quarto websites visit [Quarto.org](https://quarto.org/docs/websites).
#
# ___

# %% [markdown]
# <a href="https://github.com/Ouranosinc/energy_climate_data_guide">Energy Climate Data Guide</a> © 2026 by <a href="https://www.ouranos.ca/en">Ouranos</a> & <a href="https://www.mcmaster.ca/">McMaster University</a> is licensed under <a href="https://creativecommons.org/licenses/by-nd/4.0/">CC BY-ND 4.0</a><img src="https://mirrors.creativecommons.org/presskit/icons/cc.svg" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/by.svg" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/nd.svg" style="max-width: 1em;max-height:1em;margin-left: .2em;">
