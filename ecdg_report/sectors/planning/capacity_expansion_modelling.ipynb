# %% [markdown]
# # Capacity Expansion Modelling
#
# ## Description
# Modelling of growth in grid requirements taking demand, supply, costs, etc. as inputs to determine how to best meet demand in the lowest costs method
# [Power Sector Modeling 101](https://www.energy.gov/sites/prod/files/2016/02/f30/EPSA_Power_Sector_Modeling_FINAL_021816_0.pdf)

# %% [markdown]
# ### About Transmission and Distribution (just some notes - Marco)
#
# from a System planning perspective
#
# If you build a new line this should go here
#
# Building in a way that the system is resilience depending on how much energy I need to send to a certain condition and where should the line go.
# What kind of poles, conductors, transformers etc.
