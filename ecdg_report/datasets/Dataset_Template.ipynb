# %% [markdown]
# <!--- This is just a comment in the markup --->
#
# <!--- This section is quarto yml with a list of all refernces to be included on this page --->
# <!--- title: entry should be removed! --->
#
# ---
# title: Dataset Page Template
# nocite: |
#   @Gasset2021
#   @Gasset2025
#   @Khedhaouiria2025
#   @Munoz-Sabater2021
#
# ---
#
# # Dataset Name - Acronym
#
# This is the template for the structure of all dataset description pages.
#
# See markup code for details about how to:
#
# - make collapsable sections
# - format the tables
# - integrate references in a quarto yaml section
# - highlight things or color the text

# %% [markdown]
# ## Summary Description
#
# [Lorem ipsum dolor sit amet]{.red-text}, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud [reprehenderit in voluptate velit esse cillum]{.green-text} exercitation ullamco laboris nisi  ut aliquip ex ea commodo consequat. Duis aute irure dolor in dolore eu fugiat nulla pariatur. [Excepteur sint occaecat cupidatat non proident]{.blue-text}, sunt in culpa qui officia deserunt mollit anim id est laborum.
#
# ![A figure for the dataset (source: bibentry)](image/dataset_generic.png "A symbolic dataset"){fig-alt="A symbolic dataset" width=300}
#
# We can mark stuff [like this]{.mark-red} or <mark>like this</mark> as a reminder to deal with it later (see source for markdown implementation!).

# %% [markdown]
# ## Dataset Characteristics
# - **Current version:** lorem ipsum bla bla
# - **Temporal coverage**: lorem ipsum bla bla
# - **Temporal resolution:** lorem ipsum bla bla
# - **Spatial coverage:** lorem ipsum bla bla
# - **Spatial resolution:** lorem ipsum bla bla
# - **Data type:** lorem ipsum bla bla
# - **Web references:** <br>
#   <a href="https://www.google.com/search?q=a+link">A link to the web</a>
# - **Reference publications:**<br>
#   [See references below](#refs),

# %% [markdown]
# ## Strengths and Limitations
#
# ### Key Strengths of [Dataset]
#
#
# |Strength|Description|
# |-|---|
# |**Stength 1**            |lorem ipsum bla bla|
# |**Stength 2**            |lorem ipsum bla bla|
# |**Stength 3**.           |lorem ipsum bla bla|
# |**...**                  |...|
#
#
# : {.tbl .striped .light .sm}
#
# ### Key Limitations of [Dataset]
#
# |Limitation|Description|
# |-|---|
# |**Limitation 1**         |lorem ipsum bla bla|
# |**Limitation 2**         |lorem ipsum bla bla|
# |**Limitation 3**.        |lorem ipsum bla bla|
# |**...**                  |...|
#
#
# : {.tbl .striped .light .sm}

# %% [markdown]
# ## Expert Guidance
#
# ::: {#id1 .callout collapse="false"}
# ### A detailed discussion
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# ::: {#id1 .callout collapse="true"}
# ### A more detailed discussion
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# :::
# :::
#
# ## Example Applications
#
# *links to Electricity Sector Activities*
#
# ## Variables available in [Dataset]
#
# *For details click on variable group to uncollapse*
#
# ::: {#id .callout collapse="true"}
# ### Variable 1
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# :::
#
# ::: {#id .callout collapse="true"}
# ### Variable 2
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# :::
#
# ::: {#id .callout collapse="true"}
# ### Variable 3
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# :::
#
# ::: {#id .callout collapse="true"}
# ### ...
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# :::
#
# ## Data Access
#
# *links to access the data*
#
# ## References
# ::: {#refs}
# :::
