# %% [markdown]
# ---
# title: Adjusted and Homogenized Canadian Climate Data - AHCCD & CanHomT/P
# nocite: |
#   @Mekis2011
#   @Vincent2020
#   @Wan2007
#   @Wan2010
#   @Vincent2025
#   @Vincent2028b
#
# ---
# <!---
# ::: {.callout-warning title="Note"}
# Please add your comments on this section in [this Google Doc](https://docs.google.com/document/d/1RV-G4r5gXk-Ca694vnhJEe7U-akV7NATn7HlisB3eFw/edit?usp=drive_link).
# :::
# --->
#
# ## Summary Description
# The Adjusted and Homogenized Canadian Climate Data (AHCCD) are climate station datasets of quality-controlled and homogenized historical climate data from Environment and Climate Change Canada (ECCC). They provide long-term station-based observations for temperature, precipitation, wind and atmospheric pressure across Canada. The datasets incorporate adjustments to the historical station data for non-climatic factors (e.g., station relocations, site exposure, instrumentation changes, observer, observing procedures) to ensure consistency and reliability. AHCCD data was developed for climate research, climate change studies and trend analysis. The next generation of homogenized Canadian climate data has been published under the name Canadian Homogenized Surface Air Temperature (CanHomT V4) (@Wan2025). Publication of updated Canadian Homogenized Precipitation (CanHomP V2, @Wang2025a) and Canadian Homogenized Wind Speed data (CanHomW, @Wang2025b) shall follow. The detailed descriptions of the AHCCD/CanHom datasets are listed under the [Dataset Characteristics](#dataset-characteristics) below. [**ToDo:** Update when Wang & Feng (2025) is published]{.mark-red}
#
# ![AHCCD Temperature Stations with starting dates prior to 1990 (blue), starting dates from 1990 (green), and stations closed but with more than 30 years of data (red) (figure from @Vincent2020).](../image/AHCCD_temperature_stations.jpg "AHCCD Temperature Stations"){fig-alt="AHCCD_temperature_stations" width=600}
#
# ## Dataset Characteristics
# - **Current version:** The dataset is updated irregularly with the most recent data (although the website suggests annual updates).
# - **Temporal coverage:** Varies per station and variable, data availability ranging between 1840 and 2023
# - **Temporal resolution:** Annual, seasonal, monthly and daily values
# - **Spatial coverage:** Stations across all Canadian provinces and territories
# - **Spatial resolution:** Point locations across Canada
# - **Data type**: Historical observations from ECCC climate stations, adjusted and homogenized using statistical methods
# - **Web references:** <br>
#   [Canadian Homogenized Surface Air Temperature (CanHomT V4)](https://open.canada.ca/data/en/dataset/542b90f7-ab39-452c-be5c-2afebdc4724c)
#   <a href="https://open.canada.ca/data/en/dataset/9c4ebc00-3ea4-4fe0-8bf2-66cfe1cddd1d">Adjusted and Homogenized Canadian Climate Data (AHCCD)</a><br>
#   <a href="https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html">Technical documentation: Adjusted and homogenized Canadian climate data (AHCCD)</a>
# - **References:** <br>
#   **AHCCD**:
#   - Temperature: @Vincent2020</br>
#   - Precipitation: @Mekis2011</br>
#
#   **CanHom**:
#   - Temperature: @Wan2025 (CanHomT) </br>
#   - Precipitation: @Wang2025a (CanHomP)</br>
#   - Wind: @Wang2025b (CanHomW)
#
# ## Key Strengths of AHCCD
#
# |Strength|Description|
# |-|---|
# |**Homogenized time series**    |Adjustments remove artificial shifts due to non-climatic influences, enabling accurate trend analysis.|
# |**Long-term coverage**.        |Long term data containing many stations with over 100 years of record. |
# |**National consistency**       |Standardized methodologies applied across the Canadian network.|
# |**Data source for ECCC's climate indicators**|Used in the development of [Canadian climate change indicators](https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/climate.html) and official climate assessments.|
#
# : {.tbl .striped .light .sm}
#
# ## Limitations of AHCCD
#
# |Limitation|Description|
# |-|---|
# |**Station coverage gaps**              |Sparse in some northern or remote regions, limiting spatial completeness.|
# |**Point locations**                  |Station-based data may not represent broader regional conditions, particularly in more northern station sparse areas where the next station may be far away and in complex terrain where local conditions change over short distances.|
# |**Varying temporal coverage**        |The length of the data records vary by station and variable. There may be gaps in the station's data or a station may have been retired. The dataset is updated at irregular intervals but the latest observations may not have been processed. |
# |**Historical instrumentation issues** |Despite adjustments, early observations may be affected by poorer instrumentation or manual practices, which may increase uncertainty. |
#
# : {.tbl .striped .light .sm}

# %% [markdown]
# ## Expert Guidance
# ::: {#id .callout collapse="true"}
# ### Click to toggle section collapse
# Environment and Climate Change Canada (ECCC) produces the Adjusted and Homogenized Canadian Climate Data (AHCCD) for use in climate research and climate change studies and the data have been used in the production of climate trends (@Vincent2015, @Vincent2018b). The data are collected from Reference Climate Stations and some Canadian Aviation Weather Service stations. The AHCCD stations keep the same IDs as the Meteorological Service of Canada (MSC) stations to facilitate comparison. Note that the [governments AHCCD web site](https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data.html) and the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html#toc5) mention that AHCCD data should not be used for legal purposes since they are different from official MSC in situ records.
#
# The data are point data and may not be representative of a large region, especially in complex terrain. Althought the time series are quality controlled there may be missing values in the data, varying by variable station and time (see figure above). The length of the records for individual stations may vary significantly, and some records are from stations that have been closed. In some instances AHCCD data from nearby stations may be merged to create a longer record.
#
# The non-climatic shifts in tempertature data are identified by statistically comparing adjacent stations. Station metadata are investigated to understand non-climatic causes and determine a corrective measure if a shift has been identified. A recurring adjustment is related to the change in observing time at principal stations in 1961. The correction of the temperature record results in a slightly stronger warming in the homogenized dataset than the unadjusted data: For southern Canada this trend changed from 1.32° to 1.62°C for 1900–2018, with a smaller change for all of Canada (@Vincent2020).
#
# Precipitation data correction accounts for a number of known errors in precipitation measurements, such as underestimation of actually gauged precipitation and limits to the minimum measurable amount. Snow measurements adjust for varying snow density depending on geographical location. <mark>Updates of historical adjusted precipitation has been interrupted since Autumn 2017. This hiatus is related to the integration of manual observations to an increasingly automated station network. Updates are planned to be resumed, but no time has been specified.</mark> [Check for update on this prior to publication!]{.mark-red}
#
# <mark>Monthly datasets for Precipitation (@Wang2025a) and for Wind (@Wang2025b) have been published. @Qian2025 use CanHomT and CanHomP to derive observed changes in Canada's snowfall. The pending publication by @Wang2025a proposes a next generation of Canadian Homogenized Daily Precipitation CanHomP V2, but the data are not available at the time of this writing.</mark> [Check for update on this prior to publication!]{.mark-red}
#
# For wind speed adjustments, the key measure is the standardization of the measuring height at 10m above ground based on meta data and the measurement instrument setup. Furthermore, non-climatic causes of shifts in wind speed are identified by comparing monthly means at stations to modeled monthly means.
#
# The non-climatic shifts that are corrected in AHCCD sea level pressure and station pressure data are related to station elevation, station relocation and errors during digitization of paper records. The correction process also scans for unusually high or low values, sudden extremes or physically implausible pressure changes.
#
# More details on the methodology can be found in the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html) and the references therein.
#
# :::

# %% [markdown]
# ## Use this dataset when ...
#
# *Use cases for this dataset*
#
# ## Variables available in AHCCD
#
# *For details click on variable group to uncollapse*
#
# ::: {#id .callout collapse="true"}
# ### Temperature
# ###### Daily temperature values
# - Minimum temperature [˚C]
# - Maximum temperature [˚C]
# - Mean temperature [˚C]
# - \>330 locations in Canada
#
# For more details see the [website on daily AHCCD data](https://open.canada.ca/data/en/dataset/d6813de6-b20a-46cc-8990-01862ae15c5f)
#
# ###### Monthly, seasonal, and annual mean
# - Minimum temperature [˚C]
# - Maximum temperature [˚C]
# - Mean temperature [˚C]
# - 780 locations in Canada
#
# For more details see the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html) and the [Adjusted and homogenized Canadian climate data web page for temperature data](https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-air-temperature.html) and references therein.
# :::
#
# ::: {#id .callout collapse="true"}
# ### Precipitation
# ###### Daily precipitation values
#
# - Daily liquid precipitation (rain) [mm/period]
# - Daily solid precipitation (snow) [mm/period]
# - Daily total precipitation (rain and snow) [mm/period]
# - \>460 locations in Canada
#
# For more details see the [website on daily AHCCD data](https://open.canada.ca/data/en/dataset/d6813de6-b20a-46cc-8990-01862ae15c5f)
#
# ###### Monthly, seasonal, and annual mean
#
# - Liquid precipitation (rain) [mm/period]
# - Solid precipitation (snow) [mm/period]
# - Total precipitation (rain and snow) [mm/period]
# - 467 locations in Canada
#
# For more details see the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html) and the [Adjusted and homogenized Canadian climate data web page for precipitation data](https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/precipitation.html) and references therein.
# :::
#
# ::: {#id .callout collapse="true"}
# ### Wind
#
# ###### Monthly, seasonal and annual means of hourly wind speed
# - Wind speed [m/s]
# - Evaluated at standard 10 metre level
# - 156 locations in Canada
#
# For more details see the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html) and the [Adjusted and homogenized Canadian climate data web page for wind speed data](https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-wind-speed.html) and references therein.
# :::
#
# ::: {#id .callout collapse="true"}
# ### Pressure
#
# ###### Monthly, seasonal and annual means of hourly measurements
# - Station level pressure [Pa]
# - Sea Level pressure [Pa]
# - 626 locations in Canada
#
# For more details see the [AHCCD Technical Documentation](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-adjusted-climate-data.html) and the [Adjusted and homogenized Canadian climate data web page for wind speed data](https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-pressure.html) and references therein.
# :::
#
# ## Data Access
# Daily AHCCD station data can be found on [ClimateData.ca](https://climatedata.ca/download/#ahccd-download)
# or downloaded via the <a href="https://climate-change.canada.ca/climate-data/#/adjusted-station-data">Climate Data Extraction Tool</a> (Monthly, seasonal and annual AHCCD station data). A collection of all daily AHCCD station data in a single [netCDF](https://www.unidata.ucar.edu/software/netcdf/) file is available on [PAVICS](https://pavics.ouranos.ca/datasets.html#b).
#
# ## References
# <details>
# <summary><strong>(click to expand)</strong></summary>
#
# ::: {#refs}
# :::
#
# </details>
