# %%
import xarray as xr


ds = xr.open_dataset("/Users/marbra/Schrottplatz/maxt_dly_2020_deflated.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 366, lon: 1392, lat: 720)
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-01 2020-01-02 ... 2020-12-31
#   * lon      (lon) float64 -168.0 -167.9 -167.8 -167.7 ... -52.21 -52.12 -52.04
#   * lat      (lat) float64 25.04 25.13 25.21 25.29 ... 84.71 84.79 84.88 84.96
# Data variables:
#     crs      |S1 ...
#     maxt     (time, lat, lon) float32 ...
# Attributes:
#     CDI:                 Climate Data Interface version 1.9.10 (https://mpime...
#     Conventions:         CF-1.5
#     GDAL_AREA_OR_POINT:  Area
#     GDAL:                GDAL 1.11.4, released 2016/01/25
#     CDO:                 Climate Data Operators version 1.9.10 (https://mpime...
#     institue_id:         CFS/NRCan
#     model_id:            dly_maxt
#     references:          McKenney, D.W., Hutchinson, M., Papadopol, P., Lawre...
#     history:             Tue May 24 15:00:02 2022: ncatted -O -a units,maxt,a...
# ...

# %%
ds.maxt.isel(time=15).plot()

# %%
ds = xr.open_dataset("/Users/marbra/Schrottplatz/pcp_dly_2020_deflated.nc")
ds.pcp.isel(time=15).plot()
