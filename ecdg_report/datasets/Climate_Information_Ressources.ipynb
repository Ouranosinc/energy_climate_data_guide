# %% [markdown]
# <!--- This is just a comment in the markup --->
# <!--- This section is quarto yml with a list of all refernces to be included on this page --->
# ---
# title: Climate Information Resources
# format:
#   html:
#     toc: true
# nocite: |
#   @None2021
#
# ---

# %% [markdown]
# This document provides Climate Information Resources for the electricity sector of Canada. They are public portals and web sites that offer reliable climate information and data.
#
#
# ## PAVICS
# - explain why to go there
#
# ## EPRI
# - what it is and why use it.
#
# ## ClimateData.ca
# - A reference for climate information in Canada
#
# ## Ouranos Information Pages
# - Ressoures on climate and topics
